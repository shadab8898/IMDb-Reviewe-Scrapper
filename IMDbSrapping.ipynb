# %% [markdown]
# # IMDb Srapping

# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating'
response = requests.get(url)
soup = BeautifulSoup(response.content,'html.parser')

# %%
movie_name = []
year = []
time = []
rating = []
metascore = []
votes = []
gross = []

description = []
Director = []
Stars = []

# %%
#storing the meaningfull required data in the variable
movie_data = soup.findAll('div', attrs= {'class': 'lister-item mode-advanced'})

# %%
#calling one by one using for loop
for store in movie_data:
    name = store.h3.a.text
    movie_name.append(name)
    
    year_of_release = store.h3.find('span', class_ = 'lister-item-year text-muted unbold').text.replace('(', '').replace(')', '')
    year.append(year_of_release)
    
    runtime = store.p.find('span', class_ = 'runtime').text.replace(' min', '')
    time.append(runtime)
    
    rate = store.find('div', class_ = 'inline-block ratings-imdb-rating').text.replace('\n', '')
    rating.append(rate)
    
    meta  = store.find('span', class_ = 'metascore').text.replace(' ', '') if store.find('span', class_ = 'metascore') else '^^^^^^'
    metascore.append(meta)
    #since, gross and votes have same attributes, that's why we had created a common variable and then used indexing
    value = store.find_all('span', attrs = {'name': 'nv'})
    
    vote = value[0].text
    votes.append(vote)
    
    grosses = value[1].text if len(value) >1 else '*****'
    gross.append(grosses)
    
    # Description of the Movies
    describe = store.find_all('p', class_ = 'text-muted')
    description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
    description.append(description_)
    
    #Cast Details -- Scraping Director name and Stars 
    cast = store.find("p", class_ = '')
    cast = cast.text.replace('\n', '').split('|')
    cast = [x.strip() for x in cast]
    cast = [cast[i].replace(j, "") for i,j in enumerate(["Director:", "Stars:"])]
    Director.append(cast[0])
    Stars.append([x.strip() for x in cast[1].split(",")])

# %%
#creating a dataframe using pandas library
movie_DF = pd.DataFrame({'Name of movie': movie_name, 'Year of relase': year, 'Watchtime': time, 'Movie Rating': rating, 'Metascore': metascore, 'Votes':votes ,'Gross collection':gross  ,'Description':description  ,'Director':Director,'Star':Stars})

# %%
#Saving data in Excel file:

movie_DF.to_excel("Top_100_IMDB_Movies.xlsx")

# %%
movie_DF
# Out:
#                 Name of movie Year of relase Watchtime Movie Rating Metascore  \
# 0                    Jai Bhim           2021       164          9.5    ^^^^^^
# 1    The Shawshank Redemption           1994       142          9.3        80
# 2               The Godfather           1972       175          9.2       100
# 3             Soorarai Pottru           2020       153          9.1    ^^^^^^
# 4             The Dark Knight           2008       152          9.0        84
# ..                        ...            ...       ...          ...       ...
# 195                  Drishyam           2013       160          8.3    ^^^^^^
# 196                    Jagten           2012       115          8.3        77
# 197   Jodaeiye Nader az Simin           2011       123          8.3        95
# 198                 Incendies           2010       131          8.3        80
# 199                The Father         I 2020        97          8.3        88
#
#          Votes Gross collection  \
# 0      142,015            *****
# 1    2,495,893          $28.34M
# 2    1,721,252         $134.97M
# 3      102,565            *****
# 4    2,446,825         $534.86M
# ..         ...              ...
# 195     38,599            *****
# 196    307,534           $0.69M
# 197    233,852           $7.10M
# 198    165,309           $6.86M
# 199    107,559            *****
#
#                                            Description              Director  \
# 0    When a tribal man is arrested for a case of al...         T.J. Gnanavel
# 1    Two imprisoned men bond over a number of years...        Frank Darabont
# 2    The Godfather follows Vito Corleone Don of the...  Francis Ford Coppola
# 3    Nedumaaran Rajangam "Maara" sets out to make t...         Sudha Kongara
# 4    When the menace known as the Joker wreaks havo...     Christopher Nolan
# ..                                                 ...                   ...
# 195  A man goes to extreme lengths to save his fami...         Jeethu Joseph
# 196  A teacher lives a lonely life, all the while s...     Thomas Vinterberg
# 197  A married couple are faced with a difficult de...        Asghar Farhadi
# 198  Twins journey to the Middle East to discover t...      Denis Villeneuve
# 199  A man refuses all assistance from his daughter...        Florian Zeller
#
#                                                   Star
# 0    [Suriya, Lijo Mol Jose, Manikandan, Rajisha Vi...
# 1    [Tim Robbins, Morgan Freeman, Bob Gunton, Will...
# 2    [Marlon Brando, Al Pacino, James Caan, Diane K...
# 3    [Suriya, Paresh Rawal, Aparna Balamurali, Supe...
# 4    [Christian Bale, Heath Ledger, Aaron Eckhart, ...
# ..                                                 ...
# 195            [Mohanlal, Meena, Asha Sharath, Ansiba]
# 196  [Mads Mikkelsen, Thomas Bo Larsen, Annika Wedd...
# 197  [Payman Maadi, Leila Hatami, Sareh Bayat, Shah...
# 198  [Lubna Azabal, Mélissa Désormeaux-Poulin, Maxi...
# 199  [Anthony Hopkins, Olivia Colman, Mark Gatiss, ...
#
# [200 rows x 10 columns]
